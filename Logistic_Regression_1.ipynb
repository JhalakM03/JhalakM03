# %% [markdown]
# Q1. Explain the difference between linear regression and logistic regression models. Provide an example of
# a scenario where logistic regression would be more appropriate.

# %% [markdown]
# Difference between Linear and Logistic Regression are as follows:
#
# Linear regression: It predicts a continous outcome. Output is a real number. Assumes linear relationship between variables. It uses least square method for optimization. It assumes that residuals are normally distributed. Less robust to outliers. The dependent variable is not within a restricted range. This can handle multiple types of relationships like simple and multilinear regressions. Residuals are assumed to have constant variance. Used for forecasting effects and trends. This assumes independence of observations.
#
# Logistic regression: It predict a binary outcome. Output is probability that leads to a category. It models the log-odds of the probability of the dependent value. Its uses maximum likelihood estimation for optimization. This does not assume distribution of residuals. It is more robust to outliers as it predicts the probability. The dependent variable is restricted btetween 0 and 1. Its is mostly used for binary and multimonial outcomes in classification tasks. Residuals variance is not assumed or required. Used for risk prediction. This assumes independence of observations as well.
#
# Logistic regression would be more appropriate than linear regression in scenarios where the dependent variable is binary or categorical. For example, if we are trying to predict whether a customer will churn (i.e., stop using a product or service) based on their demographics and usage patterns, logistic regression would be a more appropriate model than linear regression. In this case, the output of the logistic regression model would be a probability value representing the likelihood of churn, rather than a continuous variable like house prices. The probability value could then be used to make decisions, such as whether to offer the customer a retention incentive.

# %% [markdown]
# Q2. What is the cost function used in logistic regression, and how is it optimized?

# %% [markdown]
# n logistic regression, the cost function is called the "logistic loss" or "cross-entropy loss" function. It measures the difference between the predicted probability values and the actual binary labels for the training data.
#
# The logistic loss function is defined as follows:
#
# ![image.png](attachment:77f56a87-0ccb-434d-9197-86ca97b46ca2.png)
#
# where y is the actual binary label (0 or 1) and hθ(x) is the predicted probability of the positive class (y=1) given the input features x.
#
# The goal of logistic regression is to find the values of the coefficients (i.e., the parameters) that minimize the logistic loss function. This is typically done using an optimization algorithm called gradient descent. Gradient descent iteratively updates the parameter values in the direction of steepest descent, moving towards the minimum of the cost function. The steps of gradient descent are as follows:
# Initialize the coefficients to some values.
#
# Calculate the predicted probabilities for the training data using the current coefficients.
#
# Calculate the gradient of the cost function with respect to each coefficient.
#
# Update each coefficient by subtracting a fraction (the learning rate) of the gradient from its current value.
#
# Repeat steps 2-4 until convergence (i.e., until the cost function stops decreasing or a maximum number of iterations is reached).

# %% [markdown]
# Q3. Explain the concept of regularization in logistic regression and how it helps prevent overfitting.

# %% [markdown]
# Regularization is a technique used to avoid overfitting in machine learning models. It does this by adding a penalty term to the objective function (also called the loss function or error function) that the model is trying to minimize.
#
# The objective function measures the error or difference between the predicted output of the model and the true output. In logistic regression, the objective function is typically the cross-entropy loss, which measures the difference between the predicted probability of the positive class and the true label (1 or 0).
#
# By adding a penalty term to the objective function, regularization helps to reduce the complexity of the model and prevent it from fitting the training data too closely. The penalty term is a hyperparameter that controls the strength of the regularization. A higher value for the penalty term leads to stronger regularization and a simpler model, while a lower value allows the model to be more complex.
#
# There are 3 types of regularizations:
#
# 1. Lasso:
#     - Adds a penalty term to the objective function equal to the absolute value of the coefficients.
#     - This leads to a sparse model, where many of the coefficients are exactly equal to zero.
#     - L1 regularization is useful for feature selection because it can automatically identify and remove unnecessary or redundant features from the model.
# 2. Ridge:
#     - Adds a penalty term to the objective function equal to the square of the coefficients.
#     - This leads to a model with all coefficients close to zero, but not necessarily equal to zero.
#     - L2 regularization is less prone to overfitting than L1 regularization and is often used as a default choice.
# 3. Elasticnet:
#     - Combines L1 and L2 regularization by adding a penalty term to the objective function that is a combination of the absolute value and square of the coefficients.
#     - This leads to a model with some coefficients equal to zero and some close to zero.
#     - Elastic Net can be useful when there are correlated features in the data and Lasso is prone to selecting only one of them.
#
# By adding a penalty term to the objective function, regularization forces the coefficients (weights) of the model to be small. This reduces the complexity of the model and makes it less prone to overfitting. For example, if we have a model with a large number of features and a large number of parameters (coefficients), regularization can help to reduce the number of non-zero coefficients and simplify the model.

# %% [markdown]
# Q4. What is the ROC curve, and how is it used to evaluate the performance of the logistic regression
# model?

# %% [markdown]
# ROC stands for Receiver Operating Characteristics, and the ROC curve is the graphical representation of the effectiveness of the binary classification model. It plots the true positive rate (TPR) vs the false positive rate (FPR) at different classification thresholds.
#
# ![image.png](attachment:8395a7a9-6f9b-4346-b30e-c00acc19588d.png)
#
# AUC stands for the Area Under the Curve, and the AUC curve represents the area under the ROC curve. It measures the overall performance of the binary classification model. As both TPR and FPR range between 0 to 1, So, the area will always lie between 0 and 1, and A greater value of AUC denotes better model performance. Our main goal is to maximize this area in order to have the highest TPR and lowest FPR at the given threshold.
#
# In an ROC curve, the x-axis typically represents the False Positive Rate (FPR), and the y-axis represents the True Positive Rate (TPR), also known as Sensitivity or Recall. So, a higher x-axis value (towards the right) on the ROC curve does indicate a higher False Positive Rate, and a higher y-axis value (towards the top) indicates a higher True Positive Rate.
#
# It shows the performance of a classification model at different classification thresholds. The AUC (Area Under the Curve) is a summary measure of the ROC curve performance.The choice of the threshold depends on the specific requirements of the problem we are trying to solve and the trade-off between false positives and false negatives that is acceptable in your context.
#
# If you want to prioritize reducing false positives (minimizing the chances of labeling something as positive when it’s not), you might choose a threshold that results in a lower false positive rate.If you want to prioritize increasing true positives (capturing as many actual positives as possible), you might choose a threshold that results in a higher true positive rate

# %% [markdown]
# Q5. What are some common techniques for feature selection in logistic regression? How do these
# techniques help improve the model's performance?

# %% [markdown]
# Feature selection is an important step in building an effective logistic regression model, especially when dealing with a large number of features. The primary goal of feature selection is to identify and retain only the most relevant features that contribute to the predictive power of the model, while:
#     removing irrelevant or redundant features. This process can improve model performance by reducing overfitting, improving interpretability, and decreasing computational complexity.
#
# Common Techniques for Feature Selection:
#
# 1. Lasso (L1) Regularization:
#     Lasso regularization adds a penalty to the loss function based on the absolute value of the coefficients. This penalty can shrink some coefficients to zero, effectively removing less important features.  It automatically performs feature selection by eliminating irrelevant features, leading to a simpler and more interpretable model.
#
# 2. Recursive Feature Elimination (RFE):
#     RFE is a wrapper method that iteratively builds a model and removes the least important feature(s). It continues this process until the desired number of features is reached. RFE systematically reduces the feature set, allowing the model to focus on the most relevant features while improving performance and reducing overfitting.
#
# 3. Univariate Feature Selection:
#     This technique evaluates each feature individually by using statistical tests (like chi-square for categorical data or ANOVA for continuous data) to measure the strength of the relationship between each feature and the target variable. It allows you to select features based on their statistical significance, which can help in removing irrelevant features that don't contribute much to the target prediction.
#
# 4. Principal Component Analysis (PCA):
#     PCA is a dimensionality reduction technique that transforms the original features into a set of uncorrelated components (principal components). The first few components explain most of the variance in the data. Although it doesn't directly select features, PCA reduces the number of features by creating a smaller set of components that capture most of the information in the original data. This can simplify the model and improve performance.
#
# 5. Backward Elimination:
#     This technique starts with all features and iteratively removes the least significant feature (based on p-values from statistical tests) until only statistically significant features remain. It ensures that only features that have a significant impact on the target variable are retained, helping to reduce noise and overfitting.
#
# 6. Forward Selection:
#     This is the opposite of backward elimination. It starts with no features and adds one feature at a time, based on which one improves the model performance the most, until adding more features doesn't significantly improve performance. It builds a model from the ground up, ensuring that only the most impactful features are included, leading to a more efficient model.
#
# Feature selection is a crucial step in the machine learning pipeline, especially for logistic regression, where it can significantly enhance the performance and usability of the model.

# %% [markdown]
# Q6. How can you handle imbalanced datasets in logistic regression? What are some strategies for dealing
# with class imbalance?

# %% [markdown]
# Handling imbalanced datasets in logistic regression is crucial because imbalanced data can lead to biased models that favor the majority class, often at the expense of the minority class. This can result in poor model performance, particularly in terms of predicting the minority class.
#
# 1. Resampling: Oversampling involves increasing the number of instances of the minority class by randomly duplicating examples or using techniques like Synthetic Minority Over-sampling Technique (SMOTE), which generates synthetic examples. Undersampling method reduces the number of instances of the majority class by randomly removing examples until the dataset is balanced. Combined resampling strategy combines both oversampling of the minority class and undersampling of the majority class to achieve a more balanced dataset.
#
# 2. Class Weighting: Many logistic regression implementations allow you to assign higher weights to the minority class in the loss function. This penalizes the model more for misclassifying minority class instances. This helps in improving recall for the minority class without changing the dataset or model. But this can reduce precision, leading to more false positives.
#
# 3. Ensemble Methods: Methods like Random Forest or Gradient Boosting can help in handling imbalanced data by combining multiple models, each of which may focus more on different aspects of the dataset. It can improve performance by reducing variance and bias, leading to better generalization on the minority class. It can also be computationally expensive and complex to implement.

# %% [markdown]
# Q7. Can you discuss some common issues and challenges that may arise when implementing logistic
# regression, and how they can be addressed? For example, what can be done if there is multicollinearity
# among the independent variables?

# %% [markdown]
# Implementing logistic regression can present several challenges that may affect the performance and reliability of the model. Below are some common issues along with strategies to address them:
#
# 1. Multicollinearity: Multicollinearity occurs when two or more independent variables (features) ar. we must remove the outliers if they are errors or anomalies. Models or loss functions can be used that are less sensitive to outliers. e highly correlated, meaning they carry similar information. This can lead to inflated standard errors for the coefficients, making it difficult to determine the individual effect of each feature on the dependent variable. We can remove one of the two variables which are highly correlated or  we could also create a composite feature that captures the information from the correlated variables.
#
# 2. Overfitting: Overfitting occurs when the model is too complex and captures noise in the training data, resulting in poor generalization to new, unseen data. It can be detected by observing a significant difference between training and validation/test accuracy. Applying Lasso and ridge regularization to penalize large coefficients reduces the model's complexity. Using techniques like k-fold cross validation to ensure the model generalizes well across different subsets of data
#
# 3. Underfitting: Underfitting happens when the model is too simple to capture the underlying pattern in the data, resulting in poor performance on both the training and test sets. It can be detected when both training and validation/test performance metrics are low, indicating that the model is not learning well from the data. Including additional relevant features may help the model capture the underlying patterns. We can also increase the model complexity if the logistic regression is too simple for the problem.
#
# 4. Imbalanced Datasets: When one class significantly outnumbers the other(s), the model may become biased towards the majority class, leading to poor performance in predicting the minority class.  Techniques like resampling, adjusted class weights and different evaluation metrics can used to balance the dataset.
#
# 5. Outliers: Outliers can disproportionately influence the model, leading to skewed coefficients and poor model performance. They can be detected using z-scores, IQR, or visualizations like box plots. We must remove the outliers if they are errors or anomalies. Models or loss functions can be used that are less sensitive to outliers.
